# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# QuantBook Analysis Tool 
# For more information see [https://www.quantconnect.com/docs/v2/our-platform/research/getting-started]
qb = QuantBook()
spy = qb.AddEquity("SPY")
history = qb.History(qb.Securities.Keys, 360, Resolution.Daily)

# Indicator Analysis
bbdf = qb.Indicator(BollingerBands(30, 2), spy.Symbol, 360, Resolution.Daily)
bbdf.drop('standarddeviation', axis=1).plot()

# %%
# Initialize QuantBook
qb = QuantBook()

# Subscribe to SPY data with QuantBook
symbol = qb.add_equity("SPY").symbol

# Make history call with QuantBook
history = qb.history(symbol, timedelta(days=10), Resolution.DAILY)
import os
print(os.getcwd())
history.to_csv("data.csv")
history

# %%
from QuantConnect.DataSource import *

aapl = qb.add_equity("AAPL", Resolution.DAILY).symbol
tiingo_aapl_symbol = qb.add_data(TiingoNews, aapl).symbol
# tiingo_symbol = qb.add_data(TiingoNews).symbol
tiingo_aapl = qb.history(tiingo_aapl_symbol, 14, Resolution.DAILY)
tiingo_aapl

# %%
tiingo_aapl.iloc[0,3]

# %%
nasdaq_appl_symbol = qb.add_data(NasdaqDataLink, 'CFTCData').symbol
nasdaq_appl = qb.history(nasdaq_appl_symbol, 14, Resolution.DAILY)
print(nasdaq_appl)

# %%
import os
os.getcwd()
